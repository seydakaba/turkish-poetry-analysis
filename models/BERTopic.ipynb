# %%
import re
import csv
import pandas as pd
import numpy as np
from bertopic import BERTopic

# %%
file = open('../allPoetry.txt', encoding="utf8")

# %%
allPoems=pd.read_csv("../allPoetry.txt",sep= " \t" ,error_bad_lines=False, engine = 'python',encoding = "utf-8")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df=pd.DataFrame()
df["allpoems"]=allPoems
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c8db3918419> in <module>
# ----> 1 df=pd.DataFrame()
#       2 df["allpoems"]=allPoems
#
# NameError: name 'pd' is not defined

# %%
docs=list(allPoems.loc[:, "allpoems"].values)

# %%
model=BERTopic(language="turkish", embedding_model="all-MiniLM-L12-v2")

# %%
topics, probs= model.fit_transform(docs)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L12-v2
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu

# %%
model.get_topic_freq()
# Out:
#    Topic  Count
# 0      0    336
# 1      1     20
# 2      2     11
# 3     -1      5

# %%
model.get_topics()
# Out:
# {-1: [('evi', 0.17940065059276292),
#   ('yıkıyorum', 0.1264969283726555),
#   ('cok', 0.0725949954368001),
#   ('taksimiyle', 0.0725949954368001),
#   ('numara', 0.0725949954368001),
#   ('kışkışlanıp', 0.0725949954368001),
#   ('hortlaklar', 0.0725949954368001),
#   ('yarına', 0.06914506882569096),
#   ('gülerle', 0.06669755094572628),
#   ('cemil', 0.06669755094572628)],
#  0: [('zaman', 0.014067955756600187),
#   ('gün', 0.01287803319430039),
#   ('kar', 0.007978052257375886),
#   ('iki', 0.00795318500807853),
#   ('dünya', 0.007895203726136321),
#   ('güzel', 0.007895203726136321),
#   ('uzun', 0.00768807884114258),
#   ('su', 0.007579149644507091),
#   ('gece', 0.007542945796416015),
#   ('kara', 0.007151358768941131)],
#  1: [('çocuk', 0.02840482054987604),
#   ('evren', 0.027014263379335577),
#   ('içinde', 0.026857394883322765),
#   ('sesleri', 0.02372429750304298),
#   ('biliniyor', 0.0232723451703722),
#   ('senle', 0.022609999693005426),
# ...

# %%
model.visualize_topics()
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/linalg/eigen/arpack/arpack.py:1593: RuntimeWarning:
#
# k >= N for N * N square matrix. Attempting to use scipy.linalg.eigh instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-97974c2b045c> in <module>
# ----> 1 model.visualize_topics()
#
# /usr/local/lib/python3.8/dist-packages/bertopic/_bertopic.py in visualize_topics(self, topics, top_n_topics, width, height)
#    2025         """
#    2026         check_is_fitted(self)
# -> 2027         return plotting.visualize_topics(self,
#    2028                                          topics=topics,
#    2029                                          top_n_topics=top_n_topics,
#
# /usr/local/lib/python3.8/dist-packages/bertopic/plotting/_topics.py in visualize_topics(topic_model, topics, top_n_topics, width, height)
# ...

# %%
model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
